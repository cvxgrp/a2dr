# %% [markdown]
# ## Examples in the paper

# %%
cd ../../examples/paper_examples
# Out:
# /Users/junziz/Desktop/[Updated]Notes_for_Classes/SEMINARS/various_research/boyd_research/distributed_aa/different versions of a2dr solvers/a2dr/examples/paper_examples

# %%
import paper_plots

# %%
# NNLS
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_nnls('../figures/nnls.pdf')
# Out:
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 8.94, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = False, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 16000, constraints m = 8000
# nnz(A) = 16000
# Setup time: 9.76e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.23e+01    1.73e+00     1.22e+01   1.77e-01
#    100| 3.94e-02    7.55e-04     3.94e-02   5.75e+00
#    200| 2.26e-02    2.76e-04     2.26e-02   1.18e+01
#    300| 1.66e-02    1.53e-04     1.66e-02   1.92e+01
#    400| 1.33e-02    1.01e-04     1.33e-02   2.54e+01
#    500| 1.10e-02    7.52e-05     1.10e-02   3.18e+01
#    600| 9.21e-03    6.55e-05     9.21e-03   3.82e+01
#    700| 7.64e-03    5.37e-05     7.64e-03   4.47e+01
#    800| 6.36e-03    4.44e-05     6.36e-03   5.11e+01
#    900| 5.29e-03    3.69e-05     5.29e-03   5.75e+01
#    999| 4.41e-03    3.07e-05     4.41e-03   6.39e+01
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 63.91609501838684
#         Total number of iterations: 1000
# Best total residual: 4.41e-03; reached at iteration 999
# ============================================================================
# Finish DRS.
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 8.94, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = True, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 16000, constraints m = 8000
# nnz(A) = 16000
# Setup time: 1.89e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.23e+01    1.73e+00     1.22e+01   9.54e-02
#    100| 5.14e-03    1.78e-04     5.14e-03   8.14e+00
#    200| 1.52e-04    4.60e-06     1.52e-04   1.62e+01
#    300| 5.75e-06    1.65e-07     5.75e-06   2.42e+01
#    378| 1.12e-06    4.44e-08     1.12e-06   3.04e+01
# ----------------------------------------------------
# Status: Solved
# Solve time: 30.378958225250244
#         Total number of iterations: 379
# Best total residual: 1.12e-06; reached at iteration 378
# ============================================================================
# nonzero entries proportion = 0.498375
# Finish A2DR.
# run time of A2DR = 30.380528211593628
# constraint violation of A2DR = 0.0
# objective value of A2DR = 76.39864074485314

# %%
# NNLS: regularization effect
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_nnls_reg('../figures/reg_effect.pdf')
# Out:
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 2.24, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = True, m_accel = 10, lam_accel = 0
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 1000, constraints m = 500
# nnz(A) = 1000
# Setup time: 1.04e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 2.44e+00    3.42e-01     2.42e+00   3.48e-02
#    100| 1.48e-02    7.12e-05     1.48e-02   8.59e-01
#    200| 9.77e-03    3.10e-05     9.77e-03   1.52e+00
#    300| 2.09e-03    2.17e-05     2.09e-03   2.23e+00
#    400| 9.88e-04    4.00e-06     9.88e-04   2.90e+00
#    500| 8.43e-04    1.96e-06     8.43e-04   3.58e+00
#    600| 7.61e-04    9.70e-07     7.61e-04   4.25e+00
#    700| 6.91e-04    8.11e-07     6.91e-04   4.91e+00
#    800| 6.34e-04    1.56e-06     6.34e-04   5.59e+00
#    900| 5.88e-04    1.12e-06     5.88e-04   6.28e+00
#    999| 5.48e-04    1.16e-06     5.48e-04   6.92e+00
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 6.92469596862793
#         Total number of iterations: 1000
# Best total residual: 5.48e-04; reached at iteration 999
# ============================================================================
# Finish A2DR no regularization.
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 2.24, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = False, anderson = True, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 1000, constraints m = 500
# nnz(A) = 1000
# Setup time: 1.59e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 2.44e+00    3.42e-01     2.42e+00   4.45e-02
#    100| 1.47e-02    7.95e-05     1.47e-02   6.88e-01
#    200| 7.71e-03    4.13e-05     7.71e-03   1.34e+00
#    300| 3.78e-03    2.99e-05     3.78e-03   2.00e+00
#    400| 1.97e-03    1.09e-05     1.97e-03   2.69e+00
#    500| 1.05e-03    4.51e-06     1.05e-03   3.36e+00
#    600| 6.12e-04    4.34e-06     6.12e-04   4.02e+00
#    700| 4.91e-04    3.90e-08     4.91e-04   4.70e+00
#    800| 4.83e-04    2.32e-08     4.83e-04   5.32e+00
#    900| 4.77e-04    1.78e-08     4.77e-04   5.96e+00
#    999| 4.73e-04    1.42e-08     4.73e-04   6.62e+00
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 6.622998952865601
#         Total number of iterations: 1000
# Best total residual: 4.73e-04; reached at iteration 999
# ============================================================================
# Finish A2DR constant regularization.
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 2.24, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = True, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 1000, constraints m = 500
# nnz(A) = 1000
# Setup time: 1.55e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 2.44e+00    3.42e-01     2.42e+00   4.25e-02
#    100| 1.46e-02    8.48e-05     1.46e-02   7.44e-01
#    200| 7.63e-03    3.99e-05     7.63e-03   1.40e+00
#    300| 3.23e-03    1.95e-05     3.23e-03   2.07e+00
#    400| 1.07e-03    5.29e-06     1.07e-03   2.76e+00
#    500| 4.16e-04    2.20e-06     4.16e-04   3.40e+00
#    600| 2.86e-04    1.68e-06     2.86e-04   4.04e+00
#    700| 1.46e-04    6.24e-07     1.46e-04   4.69e+00
#    800| 2.84e-05    2.95e-07     2.84e-05   5.37e+00
#    900| 1.09e-05    6.33e-08     1.09e-05   6.05e+00
#    999| 3.95e-06    2.40e-08     3.95e-06   6.72e+00
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 6.7199931144714355
#         Total number of iterations: 1000
# Best total residual: 3.95e-06; reached at iteration 999
# ============================================================================
# Finish A2DR adaptive regularization.

# %%
# Sparse Inverse Covariance Estimation
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_sparse_inv_covariance(50, 0.01, '../figures/sparse_inv_cov_est_small.pdf')
# Out:
# Q is positive definite? True
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 5.00, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = False, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 5000, constraints m = 2500
# nnz(A) = 5000
# Setup time: 1.02e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.85e+00    2.59e-01     1.83e+00   3.32e-02
#    100| 7.69e-03    5.30e-05     7.69e-03   3.67e-01
#    200| 5.67e-04    3.62e-06     5.67e-04   6.64e-01
#    300| 5.00e-05    2.79e-07     5.00e-05   1.00e+00
#    400| 4.65e-06    2.43e-08     4.65e-06   1.32e+00
#    465| 1.01e-06    5.13e-09     1.01e-06   1.57e+00
# ----------------------------------------------------
# Status: Solved
# Solve time: 1.5733630657196045
#         Total number of iterations: 466
# Best total residual: 1.01e-06; reached at iteration 465
# ============================================================================
# Finished DRS.
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 5.00, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = True, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 5000, constraints m = 2500
# nnz(A) = 5000
# Setup time: 1.98e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.85e+00    2.59e-01     1.83e+00   4.59e-02
#     97| 9.63e-07    5.88e-08     9.61e-07   7.63e-01
# ----------------------------------------------------
# Status: Solved
# Solve time: 0.7638897895812988
#         Total number of iterations: 98
# Best total residual: 9.63e-07; reached at iteration 97
# ============================================================================
# Finished A2DR.
# recovered sparsity = 0.2896

# %%
# Sparse Inverse Covariance Estimation
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_sparse_inv_covariance(100, 0.001, '../figures/sparse_inv_cov_est_large.pdf')
# Out:
# Q is positive definite? True
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 10.00, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = False, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 20000, constraints m = 10000
# nnz(A) = 20000
# Setup time: 1.88e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.84e+00    2.58e-01     1.82e+00   4.95e-02
#    100| 2.38e-03    2.24e-03     8.02e-04   9.01e-01
#    200| 1.12e-03    1.10e-03     1.90e-04   1.81e+00
#    300| 6.98e-04    6.73e-04     1.85e-04   2.71e+00
#    400| 4.98e-04    4.89e-04     9.39e-05   3.61e+00
#    500| 4.33e-04    3.18e-04     2.93e-04   4.51e+00
#    600| 2.53e-04    2.18e-04     1.29e-04   5.42e+00
#    700| 1.76e-04    1.74e-04     2.55e-05   6.29e+00
#    800| 1.41e-04    1.41e-04     1.32e-05   7.17e+00
#    900| 1.13e-04    1.13e-04     8.57e-06   8.07e+00
#    999| 9.03e-05    8.93e-05     1.32e-05   8.98e+00
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 8.98224687576294
#         Total number of iterations: 1000
# Best total residual: 9.03e-05; reached at iteration 999
# ============================================================================
# Finished DRS.
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 10.00, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = True, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 20000, constraints m = 10000
# nnz(A) = 20000
# Setup time: 2.19e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.84e+00    2.58e-01     1.82e+00   5.73e-02
#    100| 4.01e-03    9.74e-04     3.89e-03   2.12e+00
#    200| 2.58e-04    1.89e-04     1.75e-04   4.15e+00
#    300| 3.69e-05    3.63e-05     6.90e-06   6.26e+00
#    368| 8.45e-07    5.88e-07     6.07e-07   7.65e+00
# ----------------------------------------------------
# Status: Solved
# Solve time: 7.648461103439331
#         Total number of iterations: 369
# Best total residual: 8.45e-07; reached at iteration 368
# ============================================================================
# Finished A2DR.
# recovered sparsity = 0.0678

# %%
# l1 Trend Filtering
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_l1_trend_filtering('../figures/l1_trend_filter.pdf')
# Out:
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 22.13, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = False, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 39998, constraints m = 19998
# nnz(A) = 79992
# Setup time: 5.07e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 4.70e+00    9.22e-01     4.61e+00   1.16e-01
#    100| 5.22e-01    2.87e-03     5.22e-01   3.76e+00
#    200| 1.34e-01    7.81e-04     1.34e-01   7.33e+00
#    300| 3.84e-02    2.09e-04     3.84e-02   1.11e+01
#    400| 1.15e-02    6.22e-05     1.15e-02   1.43e+01
#    500| 3.51e-03    1.89e-05     3.51e-03   1.75e+01
#    600| 1.09e-03    5.87e-06     1.09e-03   2.04e+01
#    700| 3.40e-04    1.84e-06     3.40e-04   2.34e+01
#    800| 1.07e-04    5.79e-07     1.07e-04   2.61e+01
#    900| 3.39e-05    1.84e-07     3.39e-05   2.88e+01
#    999| 1.09e-05    5.91e-08     1.09e-05   3.13e+01
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 31.288355827331543
#         Total number of iterations: 1000
# Best total residual: 1.09e-05; reached at iteration 999
# ============================================================================
# Finished DRS.
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 22.13, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = True, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 39998, constraints m = 19998
# nnz(A) = 79992
# Setup time: 5.94e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 4.70e+00    9.22e-01     4.61e+00   1.31e-01
#    100| 4.49e-03    1.38e-04     4.48e-03   7.64e+00
#    200| 7.52e-06    5.59e-07     7.50e-06   1.47e+01
#    237| 1.04e-06    7.40e-08     1.03e-06   1.72e+01
# ----------------------------------------------------
# Status: Solved
# Solve time: 17.18395709991455
#         Total number of iterations: 238
# Best total residual: 1.04e-06; reached at iteration 237
# ============================================================================
# Finished A2DR.

# %%
# Single Commodity Flow
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_commodity_flow('../figures/single_com_flow.pdf')
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.1 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 48338
# eps = 1.00e-04, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 11002, constraints m = 34338
# Cones:	primal zero / dual free vars: 6666
# 	linear vars: 16668
# 	soc vars: 11004, soc blks: 2
# Setup time: 1.42e-01s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0|
-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.54e+01    3.96e+00     1.49e+01   9.85e-02
#    100| 3.79e-02    1.64e-02     3.42e-02   1.59e+00
#    200| 2.13e-02    1.23e-02     1.73e-02   3.19e+00
#    300| 1.86e-02    7.13e-03     1.71e-02   4.60e+00
#    400| 7.05e-03    1.85e-03     6.80e-03   6.00e+00
#    500| 1.41e-03    9.72e-04     1.02e-03   7.53e+00
#    600| 1.09e-03    6.09e-04     9.07e-04   8.94e+00
#    700| 6.79e-04    4.44e-04     5.14e-04   1.08e+01
#    800| 3.75e-04    3.47e-04     1.44e-04   1.27e+01
#    900| 3.12e-04    2.71e-04     1.54e-04   1.43e+01
#   1000| 2.42e-04    2.24e-04     9.13e-05   1.61e+01
#   1100| 3.14e-04    1.92e-04     2.48e-04   1.75e+01
#   1200| 1.75e-04    1.72e-04     2.95e-05   1.91e+01
#   1300| 1.23e-04    1.21e-04     2.38e-05   2.05e+01
#   1400| 9.79e-05    8.74e-05     4.41e-05   2.19e+01
#   1500| 8.66e-05    8.66e-05     2.85e-06   2.33e+01
#   1600| 8.66e-05    8.66e-05     1.83e-07   2.49e+01
#   1700| 1.61e-04    7.59e-05     1.42e-04   2.64e+01
#   1800| 6.55e-05    6.31e-05     1.74e-05   2.77e+01
#   1900| 6.29e-05    6.29e-05     2.57e-07   2.90e+01
#   1999| 6.29e-05    6.29e-05     1.84e-08   3.04e+01
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 30.387770175933838
#         Total number of iterations: 2000
# Best total residual: 6.29e-05; reached at iteration 1944
# ============================================================================
# DRS finished.
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 2000, t_init (after preconditioning) = 8.59, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = True, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 20
# variables n = 11000, constraints m = 4000
# nnz(A) = 18000
# Setup time: 1.90e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.54e+01    3.96e+00     1.49e+01   6.54e-02
#    100| 2.54e-02    8.93e-03     2.38e-02   2.45e+00
#    200| 1.64e-03    9.65e-04     1.32e-03   4.87e+00
#    300| 5.88e-04    4.93e-04     3.20e-04   7.59e+00
#    400| 4.28e-04    3.61e-04     2.29e-04   1.01e+01
#    500| 2.48e-04    2.40e-04     6.37e-05   1.25e+01
#    600| 2.00e-04    1.82e-04     8.25e-05   1.51e+01
#    700| 1.46e-04    1.21e-04     8.01e-05   1.76e+01
#    800| 1.23e-04    1.09e-04     5.72e-05   2.00e+01
#    900| 7.59e-05    7.59e-05     3.96e-07   2.25e+01
#   1000| 6.34e-05    6.29e-05     7.71e-06   2.49e+01
#   1100| 4.73e-06    1.15e-06     4.58e-06   2.72e+01
#   1125| 1.10e-06    1.68e-07     1.09e-06   2.77e+01
# ----------------------------------------------------
# Status: Solved
# Solve time: 27.660863876342773
#         Total number of iterations: 1126
# Best total residual: 1.10e-06; reached at iteration 1125
# ============================================================================
# A2DR finished.
# objective cvxpy raw = 2385.0745963888007, objective a2dr = 2383.7477391501634
# constraint violation cvxpy = 0.2833336907782897, constraint violation a2dr = 1.60269725729902e-06

# %%
# Optimal Control
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_optimal_control('../figures/opt_cont.pdf')
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.1 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 669731
# eps = 1.00e-04, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 4641, constraints m = 11031
# Cones:	primal zero / dual free vars: 3150
# 	linear vars: 3201
# 	soc vars: 4680, soc blks: 40
# Setup time: 3.56e-01s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0|

# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 18.53, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = True, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 4600, constraints m = 3150
# nnz(A) = 658650
# Setup time: 1.17e-01
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 2.13e+01    2.13e+01     0.00e+00   8.27e-01
#     82| 9.69e-07    8.22e-07     5.14e-07   5.84e+01
# ----------------------------------------------------
# Status: Solved
# Solve time: 58.36156415939331
#         Total number of iterations: 83
# Best total residual: 9.69e-07; reached at iteration 82
# ============================================================================
# Finished A2DR.
# linear constr vio cvxpy = 2.7556643195434303, linear constr_vio a2dr = 9.285175615825743e-07
# norm constr vio cvxpy = 1.370021882748846, norm constr vio a2dr = 1.0
# objective cvxpy = 33856.96128869978, objective cvxpy raw = 36047.82290476538, objective a2dr = 37986.57967853125

# %%
# Coupled QP
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_coupled_qp('../figures/coupled_qp.pdf')
# Out:
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 12.23, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = False, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 2400, constraints m = 50
# nnz(A) = 120000
# Setup time: 5.11e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 5.19e+01    3.32e+01     3.98e+01   7.78e-01
#    100| 1.74e+00    1.74e+00     1.88e-02   6.11e+01
#    200| 1.38e-01    1.38e-01     1.25e-03   1.22e+02
#    300| 1.42e-02    1.42e-02     1.23e-04   1.84e+02
#    400| 1.68e-03    1.68e-03     1.42e-05   2.44e+02
#    500| 2.15e-04    2.15e-04     1.82e-06   3.05e+02
#    600| 2.87e-05    2.87e-05     2.45e-07   3.66e+02
#    700| 3.96e-06    3.96e-06     3.39e-08   4.27e+02
#    749| 1.51e-06    1.51e-06     1.37e-08   4.58e+02
# ----------------------------------------------------
# Status: Solved
# Solve time: 457.69253396987915
#         Total number of iterations: 750
# Best total residual: 1.51e-06; reached at iteration 749
# ============================================================================
# DRS finished.
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 12.23, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = True, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 2400, constraints m = 50
# nnz(A) = 120000
# Setup time: 5.97e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 5.19e+01    3.32e+01     3.98e+01   8.35e-01
#     57| 1.17e-06    1.17e-06     3.91e-08   3.55e+01
# ----------------------------------------------------
# Status: Solved
# Solve time: 35.46021103858948
#         Total number of iterations: 58
# Best total residual: 1.17e-06; reached at iteration 57
# ============================================================================
# A2DR finished.
# objective value of A2DR = 89696.99862846492
# constraint violation of A2DR = 1.2880757683973192e-05

# %%
# Multi-task Regularized Logistic Regression
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_multi_task_logistic('../figures/multitask_reglog.pdf')
# Out:
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 7.79, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = False, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 13000, constraints m = 8000
# nnz(A) = 1513000
# Setup time: 2.67e-01
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 2.88e+00    1.29e+00     2.58e+00   6.75e-01
#    100| 1.80e-01    1.54e-03     1.80e-01   3.07e+01
#    200| 8.73e-02    3.93e-04     8.73e-02   5.39e+01
#    300| 5.64e-02    1.76e-04     5.64e-02   7.55e+01
#    400| 4.09e-02    9.90e-05     4.09e-02   9.63e+01
#    500| 3.16e-02    6.33e-05     3.16e-02   1.16e+02
#    600| 2.54e-02    4.39e-05     2.54e-02   1.34e+02
#    700| 2.10e-02    3.21e-05     2.10e-02   1.52e+02
#    800| 1.78e-02    2.45e-05     1.78e-02   1.70e+02
#    900| 1.52e-02    1.93e-05     1.52e-02   1.88e+02
#    999| 1.33e-02    1.55e-05     1.33e-02   2.06e+02
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 206.04451394081116
#         Total number of iterations: 1000
# Best total residual: 1.33e-02; reached at iteration 999
# ============================================================================
# DRS finished.
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 7.79, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = True, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 13000, constraints m = 8000
# nnz(A) = 1513000
# Setup time: 3.01e-01
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 2.88e+00    1.29e+00     2.58e+00   6.69e-01
#    100| 2.19e-03    6.24e-05     2.18e-03   2.36e+01
#    200| 3.91e-04    2.01e-07     3.91e-04   4.23e+01
#    300| 7.09e-05    4.95e-08     7.09e-05   6.01e+01
#    400| 8.73e-06    5.24e-09     8.73e-06   7.77e+01
#    500| 1.47e-06    9.47e-10     1.47e-06   9.47e+01
#    532| 9.27e-07    3.64e-10     9.27e-07   1.00e+02
# ----------------------------------------------------
# Status: Solved
# Solve time: 100.09134101867676
#         Total number of iterations: 533
# Best total residual: 9.27e-07; reached at iteration 532
# ============================================================================
# A2DR finished.

# %% [markdown]
# ## Check 1: OSQP/SCS actually succeed on coupled QP

# %%
import numpy as np
from cvxpy import *

np.random.seed(1)
K = 8 # even 200 works # number of blocks
p = 50 # number of coupling constraints
nk = 300 # variable dimension of each subproblem QP
mk = 200 # constrain dimension of each subproblem QP
A_list = [np.random.randn(p, nk) for k in range(K)]
F_list = [np.random.randn(mk, nk) for k in range(K)]
q_list = [np.random.randn(nk) for k in range(K)]
x_list = [np.random.randn(nk) for k in range(K)]
g_list = [F_list[k].dot(x_list[k])+0.1 for k in range(K)]
A = np.hstack(A_list)
x = np.hstack(x_list)
b = A.dot(x)
P_list = [np.random.randn(nk,nk) for k in range(K)]
Q_list = [P_list[k].T.dot(P_list[k]) for k in range(K)]

var_name_lst = []
for k in range(K):
    var_name_lst.append('x'+str(k))
    
obj = 0
constr_lhs = 0
constr = []
for k in range(K):
    vars()[var_name_lst[k]] = Variable(nk)
    obj += quad_form(vars()[var_name_lst[k]],Q_list[k]) + q_list[k]*vars()[var_name_lst[k]]
    constr_lhs += A_list[k] * vars()[var_name_lst[k]]
    constr += [F_list[k]*vars()[var_name_lst[k]] <= g_list[k]]
constr += [constr_lhs == b]

prob1 = Problem(Minimize(obj), constr)
prob1.solve(solver='OSQP', eps_abs=1e-6, eps_rel=1e-8, verbose=True) 

prob2 = Problem(Minimize(obj), constr)
prob2.solve(solver='SCS', eps=1e-6, verbose=True)
# Out:
# -----------------------------------------------------------------
#            OSQP v0.6.0  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2019
# -----------------------------------------------------------------
# problem:  variables n = 2400, constraints m = 1650
#           nnz(P) + nnz(A) = 961200
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-06, eps_rel = 1.0e-08,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1  -2.8634e+00   1.04e+02   4.56e+06   1.00e-01   3.13e-01s
#  150   8.9697e+04   8.02e-07   3.25e-07   8.25e-03   9.50e-01s
# plsh   8.9697e+04   3.51e-13   1.03e-10   --------   1.11e+00s
#
# status:               solved
# solution polish:      successful
# number of iterations: 150
# optimal objective:    89696.9987
# run time:             1.11e+00s
# optimal rho estimate: 2.77e-02
#
# ----------------------------------------------------------------------------
# 	SCS v2.1.1 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1320016
# eps = 1.00e-06, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 2408, constraints m = 4066
# Cones:	primal zero / dual free vars: 50
# 	linear vars: 1600
# 	soc vars: 2416, soc blks: 8
# Setup time: 6.53e-01s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 5.58e+19  9.84e+19  1.00e+00 -1.48e+24  2.43e+24  3.64e+24  1.84e-02
#    100| 6.16e-06  1.48e-05  3.47e-07  8.97e+04  8.97e+04  5.28e-13  7.20e-01
#    140| 2.07e-07  4.65e-07  4.60e-09  8.97e+04  8.97e+04  1.74e-13  9.98e-01
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 9.98e-01s
# 	Lin-sys: nnz in L factor: 2165315, avg solve time: 6.27e-03s
# 	Cones: avg projection time: 8.60e-06s
# 	Acceleration: avg step time: 4.93e-04s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 3.8828e-14, dist(y, K*) = 2.7285e-12, s'y/|s||y| = -2.3726e-18
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 2.0657e-07
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 4.6466e-07
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 4.6029e-09
# ----------------------------------------------------------------------------
# c'x = 89696.9979, -b'y = 89696.9987
# ============================================================================
# 89696.99785560426

# %%
## Coupled QP (rerun)
# check why slightly different results from the above? 
# because OSQP's random generator is independent of np.random.seed?
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_coupled_qp('../figures/coupled_qp_rerun.pdf')
# Out:
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 12.23, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = False, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 2400, constraints m = 50
# nnz(A) = 120000
# Setup time: 4.68e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 5.19e+01    3.32e+01     3.98e+01   7.40e-01
#    100| 1.74e+00    1.74e+00     1.88e-02   6.07e+01
#    200| 1.38e-01    1.38e-01     1.25e-03   1.21e+02
#    300| 1.42e-02    1.42e-02     1.23e-04   1.81e+02
#    400| 1.68e-03    1.68e-03     1.42e-05   2.41e+02
#    500| 2.15e-04    2.15e-04     1.82e-06   3.01e+02
#    600| 2.87e-05    2.87e-05     2.45e-07   3.67e+02
#    700| 3.96e-06    3.96e-06     3.39e-08   4.32e+02
#    749| 1.51e-06    1.51e-06     1.37e-08   4.63e+02
# ----------------------------------------------------
# Status: Solved
# Solve time: 462.93538784980774
#         Total number of iterations: 750
# Best total residual: 1.51e-06; reached at iteration 749
# ============================================================================
# DRS finished.
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 12.23, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = True, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 2400, constraints m = 50
# nnz(A) = 120000
# Setup time: 4.94e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 5.19e+01    3.32e+01     3.98e+01   7.60e-01
#     57| 1.17e-06    1.17e-06     3.91e-08   3.49e+01
# ----------------------------------------------------
# Status: Solved
# Solve time: 34.89945697784424
#         Total number of iterations: 58
# Best total residual: 1.17e-06; reached at iteration 57
# ============================================================================
# A2DR finished.
# objective value of A2DR = 89696.99862846492
# constraint violation of A2DR = 1.2880757683973192e-05

# %% [markdown]
# ## Check 2: Slowness and inaccuracy of scipy.optimize.nnls on NNLS

# %%
import numpy as np
from scipy import sparse
from scipy.optimize import nnls
import time
np.random.seed(1)
m, n = 10000, 8000
density = 0.001
X = sparse.random(m, n, density=density, data_rvs=np.random.randn)
y = np.random.randn(m)

# %%
# Solve with scipy.optimize.nnls
t0 = time.time()
res = nnls(sparse.csr_matrix(X).todense(),y)
t1 = time.time()
print('run time = {}'.format(t1-t0))
print('constraint violation = {}'.format(np.min(res[0])))
print('objective value = {}'.format(np.linalg.norm(X.dot(res[0]) - y)))
# Out:
# run time = 557.026547908783
# constraint violation = 0.0
# objective value = 76.39864074482281

# %%
# Solve with OSQP
from cvxpy import *
beta = Variable(n)
obj = sum_squares(X*beta-y)
constr = [beta >= 0]
prob = Problem(Minimize(obj), constr)
prob.solve(solver='OSQP', verbose=True)
beta = beta.value
print('constraint violation = {}'.format(np.min(beta)))
print('objective value = {}'.format(np.linalg.norm(X.dot(beta)-y)))
# Out:
# -----------------------------------------------------------------
#            OSQP v0.6.0  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2019
# -----------------------------------------------------------------
# problem:  variables n = 18000, constraints m = 18000
#           nnz(P) + nnz(A) = 108000
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   3.93e+00   9.68e+02   1.00e-01   5.81e+01s
#  200   5.6140e+03   1.14e-01   2.72e-03   1.00e-01   6.90e+01s
#  400   5.8044e+03   2.25e-02   2.92e-04   1.00e-01   8.00e+01s
#  550   5.8368e+03   2.59e-06   5.65e-05   1.56e+00   1.45e+02s
# plsh   5.8368e+03   1.63e-15   5.98e-15   --------   2.04e+02s
#
# status:               solved
# solution polish:      successful
# number of iterations: 550
# optimal objective:    5836.7523
# run time:             2.04e+02s
# optimal rho estimate: 2.59e-01
#
# constraint violation = -1.4669704317854836e-19
# objective value = 76.39864074482281

# %%
# Solve with SCS
from cvxpy import *
beta = Variable(n)
obj = sum_squares(X*beta-y)
constr = [beta >= 0]
prob = Problem(Minimize(obj), constr)
prob.solve(solver='SCS', eps=1e-6, verbose=True)
beta = beta.value
print('constraint violation = {}'.format(np.min(beta)))
print('objective value = {}'.format(np.linalg.norm(X.dot(beta)-y)))
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.1 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 88002
# eps = 1.00e-06, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 8001, constraints m = 18002
# Cones:	linear vars: 8000
# 	soc vars: 10002, soc blks: 1
# Setup time: 7.60e+01s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 5.81e+20  7.38e+20  1.00e+00 -3.53e+22  1.09e+23  6.61e+22  1.32e-01
#    100| 8.34e-02  2.36e-01  5.01e-05  5.67e+03  5.67e+03  4.11e-15  7.53e+00
#    200| 1.13e-02  3.20e-02  2.06e-07  5.83e+03  5.83e+03  9.32e-15  1.50e+01
#    300| 2.50e-03  8.70e-03  9.28e-07  5.83e+03  5.83e+03  3.75e-16  2.25e+01
#    400| 1.80e-03  6.64e-03  1.02e-06  5.83e+03  5.83e+03  6.88e-15  3.00e+01
#    500| 6.31e-04  2.43e-03  5.20e-07  5.84e+03  5.84e+03  2.99e-15  3.75e+01
#    600| 5.07e-04  1.41e-03  2.95e-07  5.84e+03  5.84e+03  5.79e-15  4.48e+01
#    700| 6.10e-04  2.00e-03  7.68e-08  5.84e+03  5.84e+03  8.38e-15  5.22e+01
#    800| 3.15e-04  1.14e-03  2.61e-08  5.84e+03  5.84e+03  3.93e-15  5.96e+01
#    900| 7.27e-05  2.00e-04  1.89e-08  5.84e+03  5.84e+03  2.38e-15  6.70e+01
#   1000| 2.91e-05  9.62e-05  1.60e-09  5.84e+03  5.84e+03  1.57e-15  7.44e+01
#   1100| 2.21e-05  7.51e-05  1.04e-08  5.84e+03  5.84e+03  5.04e-15  8.17e+01
#   1200| 1.40e-05  5.33e-05  2.75e-09  5.84e+03  5.84e+03  4.80e-15  8.91e+01
#   1300| 9.04e-06  3.64e-05  1.55e-09  5.84e+03  5.84e+03  4.52e-15  9.65e+01
#   1400| 6.25e-06  2.35e-05  1.64e-09  5.84e+03  5.84e+03  4.49e-15  1.04e+02
#   1500| 4.76e-06  1.78e-05  4.32e-10  5.84e+03  5.84e+03  7.67e-15  1.11e+02
#   1600| 3.53e-06  1.43e-05  2.03e-10  5.84e+03  5.84e+03  1.23e-15  1.19e+02
#   1700| 2.70e-06  9.63e-06  8.24e-11  5.84e+03  5.84e+03  6.35e-15  1.26e+02
#   1800| 1.93e-06  6.87e-06  5.24e-10  5.84e+03  5.84e+03  1.65e-15  1.33e+02
#   1900| 1.16e-06  4.25e-06  1.65e-10  5.84e+03  5.84e+03  1.28e-15  1.41e+02
#   2000| 7.80e-07  2.66e-06  3.95e-12  5.84e+03  5.84e+03  1.28e-14  1.48e+02
#   2100| 5.21e-07  1.70e-06  4.62e-11  5.84e+03  5.84e+03  4.84e-15  1.56e+02
#   2200| 3.64e-07  1.19e-06  3.21e-11  5.84e+03  5.84e+03  1.21e-14  1.63e+02
#   2220| 2.73e-07  8.57e-07  4.28e-11  5.84e+03  5.84e+03  9.87e-15  1.65e+02
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 1.65e+02s
# 	Lin-sys: nnz in L factor: 26759681, avg solve time: 7.14e-02s
# 	Cones: avg projection time: 5.84e-05s
# 	Acceleration: avg step time: 2.26e-03s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 6.8212e-12, dist(y, K*) = 0.0000e+00, s'y/|s||y| = -2.0519e-15
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 2.7341e-07
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 8.5734e-07
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 4.2833e-11
# ----------------------------------------------------------------------------
# c'x = 5836.7521, -b'y = 5836.7521
# ============================================================================
# constraint violation = -2.410122311905543e-06
# objective value = 76.39864383957534

# %%
## NNLS (rerun)
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_nnls('../figures/nnls_rerun.pdf')
# Out:
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 8.94, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = False, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 16000, constraints m = 8000
# nnz(A) = 16000
# Setup time: 1.49e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.23e+01    1.73e+00     1.22e+01   9.20e-02
#    100| 3.94e-02    7.55e-04     3.94e-02   5.68e+00
#    200| 2.26e-02    2.76e-04     2.26e-02   1.12e+01
#    300| 1.66e-02    1.53e-04     1.66e-02   1.68e+01
#    400| 1.33e-02    1.01e-04     1.33e-02   2.24e+01
#    500| 1.10e-02    7.52e-05     1.10e-02   2.79e+01
#    600| 9.21e-03    6.55e-05     9.21e-03   3.36e+01
#    700| 7.64e-03    5.37e-05     7.64e-03   3.94e+01
#    800| 6.36e-03    4.44e-05     6.36e-03   4.51e+01
#    900| 5.29e-03    3.69e-05     5.29e-03   5.09e+01
#    999| 4.41e-03    3.07e-05     4.41e-03   5.66e+01
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 56.59048128128052
#         Total number of iterations: 1000
# Best total residual: 4.41e-03; reached at iteration 999
# ============================================================================
# Finish DRS.
# ----------------------------------------------------------------
# a2dr v0.1 - Prox-Affine Distributed Convex Optimization Solver
#                  (c) Anqi Fu, Junzi Zhang
#                  Stanford University, 2019
# ----------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 8.94, eps_abs = 1e-06, eps_rel = 1e-08
# precond = True, ada_reg = True, anderson = True, m_accel = 10, lam_accel = 1e-08
# aa_method = lstsq, D_safe = 1000000.00, eps_safe = 1e-06, M_safe = 10
# variables n = 16000, constraints m = 8000
# nnz(A) = 16000
# Setup time: 2.06e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.23e+01    1.73e+00     1.22e+01   9.70e-02
#    100| 5.14e-03    1.78e-04     5.14e-03   7.19e+00
#    200| 1.52e-04    4.60e-06     1.52e-04   1.44e+01
#    300| 5.75e-06    1.65e-07     5.75e-06   2.16e+01
#    378| 1.12e-06    4.44e-08     1.12e-06   2.72e+01
# ----------------------------------------------------
# Status: Solved
# Solve time: 27.177469968795776
#         Total number of iterations: 379
# Best total residual: 1.12e-06; reached at iteration 378
# ============================================================================
# nonzero entries proportion = 0.498375
# Finish A2DR.
# run time of A2DR = 27.178575038909912
# constraint violation of A2DR = 0.0
# objective value of A2DR = 76.39864074485314
