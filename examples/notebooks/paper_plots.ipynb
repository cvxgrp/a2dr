# %% [markdown]
# ## Examples in the paper

# %%
cd ../../examples/paper_examples
# Out:
# /Users/junziz/Desktop/[Updated]Notes_for_Classes/SEMINARS/various_research/boyd_research/distributed_aa/different versions of a2dr solvers/a2dr_pypi/examples/paper_examples

# %%
import paper_plots

# %%
# NNLS
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_nnls('../figures/nnls.pdf')
# Out:
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 8.94
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = False, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 16000, constraints m = 8000
# nnz(A) = 16000
# Setup time: 2.40e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.23e+01    1.73e+00     1.22e+01   1.13e-01
#    100| 3.94e-02    7.55e-04     3.94e-02   7.23e+00
#    200| 2.26e-02    2.76e-04     2.26e-02   1.47e+01
#    300| 1.66e-02    1.53e-04     1.66e-02   2.25e+01
#    400| 1.33e-02    1.01e-04     1.33e-02   2.87e+01
#    500| 1.10e-02    7.52e-05     1.10e-02   3.51e+01
#    600| 9.21e-03    6.55e-05     9.21e-03   4.14e+01
#    700| 7.64e-03    5.37e-05     7.64e-03   4.77e+01
#    800| 6.36e-03    4.44e-05     6.36e-03   5.41e+01
#    900| 5.29e-03    3.69e-05     5.29e-03   6.07e+01
#    999| 4.41e-03    3.07e-05     4.41e-03   6.72e+01
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 6.72e+01
# Total number of iterations: 1000
# Best total residual: 4.41e-03; reached at iteration 999
# ======================================================================
# Finish DRS.
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 8.94
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = True, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 16000, constraints m = 8000
# nnz(A) = 16000
# Setup time: 2.48e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.23e+01    1.73e+00     1.22e+01   1.16e-01
#    100| 5.14e-03    1.78e-04     5.14e-03   7.99e+00
#    200| 1.52e-04    4.60e-06     1.52e-04   1.59e+01
#    300| 5.75e-06    1.65e-07     5.75e-06   2.39e+01
#    378| 1.12e-06    4.44e-08     1.12e-06   3.01e+01
# ----------------------------------------------------
# Status: Solved
# Solve time: 3.01e+01
# Total number of iterations: 379
# Best total residual: 1.12e-06; reached at iteration 378
# ======================================================================
# nonzero entries proportion = 0.498375
# Finish A2DR.
# run time of A2DR = 30.13329315185547
# constraint violation of A2DR = 0.0
# objective value of A2DR = 76.39864074485314

# %%
# NNLS: regularization effect
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_nnls_reg('../figures/reg_effect.pdf')
# Out:
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 2.24
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = True, m_accel = 10
# lam_accel = 0.00e+00, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 1000, constraints m = 500
# nnz(A) = 1000
# Setup time: 1.22e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 2.44e+00    3.42e-01     2.42e+00   3.40e-02
#    100| 1.48e-02    7.12e-05     1.48e-02   6.80e-01
#    200| 9.77e-03    3.10e-05     9.77e-03   1.34e+00
#    300| 2.09e-03    2.17e-05     2.09e-03   2.06e+00
#    400| 9.88e-04    4.00e-06     9.88e-04   2.76e+00
#    500| 8.43e-04    1.96e-06     8.43e-04   3.48e+00
#    600| 7.61e-04    9.70e-07     7.61e-04   4.18e+00
#    700| 6.91e-04    8.11e-07     6.91e-04   4.86e+00
#    800| 6.34e-04    1.56e-06     6.34e-04   5.53e+00
#    900| 5.88e-04    1.12e-06     5.88e-04   6.22e+00
#    999| 5.48e-04    1.16e-06     5.48e-04   6.90e+00
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 6.90e+00
# Total number of iterations: 1000
# Best total residual: 5.48e-04; reached at iteration 999
# ======================================================================
# Finish A2DR no regularization.
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 2.24
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = False, anderson = True, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 1000, constraints m = 500
# nnz(A) = 1000
# Setup time: 2.36e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 2.44e+00    3.42e-01     2.42e+00   5.01e-02
#    100| 1.47e-02    7.95e-05     1.47e-02   7.54e-01
#    200| 7.71e-03    4.13e-05     7.71e-03   1.46e+00
#    300| 3.78e-03    2.99e-05     3.78e-03   2.15e+00
#    400| 1.97e-03    1.09e-05     1.97e-03   2.82e+00
#    500| 1.05e-03    4.51e-06     1.05e-03   3.49e+00
#    600| 6.12e-04    4.34e-06     6.12e-04   4.22e+00
#    700| 4.91e-04    3.90e-08     4.91e-04   4.95e+00
#    800| 4.83e-04    2.32e-08     4.83e-04   5.66e+00
#    900| 4.77e-04    1.78e-08     4.77e-04   6.36e+00
#    999| 4.73e-04    1.42e-08     4.73e-04   7.01e+00
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 7.01e+00
# Total number of iterations: 1000
# Best total residual: 4.73e-04; reached at iteration 999
# ======================================================================
# Finish A2DR constant regularization.
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 2.24
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = True, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 1000, constraints m = 500
# nnz(A) = 1000
# Setup time: 1.65e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 2.44e+00    3.42e-01     2.42e+00   4.29e-02
#    100| 1.46e-02    8.48e-05     1.46e-02   7.25e-01
#    200| 7.63e-03    3.99e-05     7.63e-03   1.41e+00
#    300| 3.23e-03    1.95e-05     3.23e-03   2.10e+00
#    400| 1.07e-03    5.29e-06     1.07e-03   2.99e+00
#    500| 4.16e-04    2.20e-06     4.16e-04   3.92e+00
#    600| 2.86e-04    1.68e-06     2.86e-04   4.68e+00
#    700| 1.46e-04    6.24e-07     1.46e-04   5.38e+00
#    800| 2.84e-05    2.95e-07     2.84e-05   6.07e+00
#    900| 1.09e-05    6.33e-08     1.09e-05   6.74e+00
#    999| 3.95e-06    2.40e-08     3.95e-06   7.41e+00
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 7.41e+00
# Total number of iterations: 1000
# Best total residual: 3.95e-06; reached at iteration 999
# ======================================================================
# Finish A2DR adaptive regularization.

# %%
# Sparse Inverse Covariance Estimation
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_sparse_inv_covariance(50, 0.01, '../figures/sparse_inv_cov_est_small.pdf')
# Out:
# Q is positive definite? True
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 5.00
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = False, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 5000, constraints m = 2500
# nnz(A) = 5000
# Setup time: 1.08e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.85e+00    2.59e-01     1.83e+00   3.40e-02
#    100| 7.69e-03    5.30e-05     7.69e-03   3.96e-01
#    200| 5.67e-04    3.62e-06     5.67e-04   7.33e-01
#    300| 5.00e-05    2.79e-07     5.00e-05   1.05e+00
#    400| 4.65e-06    2.43e-08     4.65e-06   1.37e+00
#    465| 1.01e-06    5.13e-09     1.01e-06   1.61e+00
# ----------------------------------------------------
# Status: Solved
# Solve time: 1.61e+00
# Total number of iterations: 466
# Best total residual: 1.01e-06; reached at iteration 465
# ======================================================================
# Finished DRS.
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 5.00
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = True, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 5000, constraints m = 2500
# nnz(A) = 5000
# Setup time: 1.94e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.85e+00    2.59e-01     1.83e+00   4.56e-02
#     97| 9.63e-07    5.88e-08     9.61e-07   7.14e-01
# ----------------------------------------------------
# Status: Solved
# Solve time: 7.14e-01
# Total number of iterations: 98
# Best total residual: 9.63e-07; reached at iteration 97
# ======================================================================
# Finished A2DR.
# recovered sparsity = 0.2896

# %%
# Sparse Inverse Covariance Estimation
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_sparse_inv_covariance(100, 0.001, '../figures/sparse_inv_cov_est_large.pdf')
# Out:
# Q is positive definite? True
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 10.00
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = False, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 20000, constraints m = 10000
# nnz(A) = 20000
# Setup time: 1.86e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.84e+00    2.58e-01     1.82e+00   4.83e-02
#    100| 2.38e-03    2.24e-03     8.02e-04   9.20e-01
#    200| 1.12e-03    1.10e-03     1.90e-04   1.83e+00
#    300| 6.98e-04    6.73e-04     1.85e-04   2.76e+00
#    400| 4.98e-04    4.89e-04     9.39e-05   3.67e+00
#    500| 4.33e-04    3.18e-04     2.93e-04   4.59e+00
#    600| 2.53e-04    2.18e-04     1.29e-04   5.67e+00
#    700| 1.76e-04    1.74e-04     2.55e-05   6.76e+00
#    800| 1.41e-04    1.41e-04     1.32e-05   7.94e+00
#    900| 1.13e-04    1.13e-04     8.57e-06   8.95e+00
#    999| 9.03e-05    8.93e-05     1.32e-05   1.00e+01
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 1.00e+01
# Total number of iterations: 1000
# Best total residual: 9.03e-05; reached at iteration 999
# ======================================================================
# Finished DRS.
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 10.00
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = True, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 20000, constraints m = 10000
# nnz(A) = 20000
# Setup time: 2.40e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.84e+00    2.58e-01     1.82e+00   6.28e-02
#    100| 4.01e-03    9.74e-04     3.89e-03   2.39e+00
#    200| 1.14e-03    2.52e-04     1.11e-03   4.67e+00
#    300| 1.73e-03    2.46e-04     1.72e-03   6.98e+00
#    377| 9.93e-07    5.60e-07     8.20e-07   8.62e+00
# ----------------------------------------------------
# Status: Solved
# Solve time: 8.62e+00
# Total number of iterations: 378
# Best total residual: 9.93e-07; reached at iteration 377
# ======================================================================
# Finished A2DR.
# recovered sparsity = 0.0678

# %%
# l1 Trend Filtering
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_l1_trend_filtering('../figures/l1_trend_filter.pdf')
# Out:
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 22.13
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = False, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 39998, constraints m = 19998
# nnz(A) = 79992
# Setup time: 4.70e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 4.70e+00    9.22e-01     4.61e+00   1.14e-01
#    100| 5.22e-01    2.87e-03     5.22e-01   4.10e+00
#    200| 1.34e-01    7.81e-04     1.34e-01   7.72e+00
#    300| 3.84e-02    2.09e-04     3.84e-02   1.12e+01
#    400| 1.15e-02    6.22e-05     1.15e-02   1.44e+01
#    500| 3.51e-03    1.89e-05     3.51e-03   1.76e+01
#    600| 1.09e-03    5.87e-06     1.09e-03   2.06e+01
#    700| 3.40e-04    1.84e-06     3.40e-04   2.35e+01
#    800| 1.07e-04    5.79e-07     1.07e-04   2.61e+01
#    900| 3.39e-05    1.84e-07     3.39e-05   2.88e+01
#    999| 1.09e-05    5.91e-08     1.09e-05   3.12e+01
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 3.12e+01
# Total number of iterations: 1000
# Best total residual: 1.09e-05; reached at iteration 999
# ======================================================================
# Finished DRS.
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 22.13
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = True, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 39998, constraints m = 19998
# nnz(A) = 79992
# Setup time: 4.89e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 4.70e+00    9.22e-01     4.61e+00   1.17e-01
#    100| 4.49e-03    1.38e-04     4.48e-03   7.37e+00
#    200| 7.52e-06    5.59e-07     7.50e-06   1.42e+01
#    237| 1.04e-06    7.40e-08     1.03e-06   1.65e+01
# ----------------------------------------------------
# Status: Solved
# Solve time:
# ----------------------------------------------------------------------------
# Status: Solved/Inaccurate
# Hit max_iters, solution may be inaccurate, returning best found solution.
# Timing: Solve time: 3.99e+01s
# 	Lin-sys: nnz in L factor: 457618, avg solve time: 2.16e-03s
# 	Cones: avg projection time: 6.88e-05s
# 	Acceleration: avg step time: 4.78e-03s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 4.4338e-12, dist(y, K*) = 1.3642e-12, s'y/|s||y| = -2.7292e-15
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.2452e-03
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.4729e-03
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.8088e-06
# ----------------------------------------------------------------------------
# c'x = 2382.8309, -b'y = 2382.8396
# ============================================================================
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 2000, t_init (after preconditioning) = 8.59
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = False, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 20
# variables n = 11000, constraints m = 4000
# nnz(A) = 18000
# Setup time: 3.27e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.54e+01    3.96e+00     1.49e+01   7.92e-02
#    100| 3.79e-02    1.64e-02     3.42e-02   2.13e+00
#    200| 2.13e-02    1.23e-02     1.73e-02   3.89e+00
#    300| 1.86e-02    7.13e-03     1.71e-02   5.42e+00
#    400| 7.05e-03    1.85e-03     6.80e-03   6.94e+00
#    500| 1.41e-03    9.72e-04     1.02e-03   8.48e+00
#    600| 1.09e-03    6.09e-04     9.07e-04   1.02e+01
#    700| 6.79e-04    4.44e-04     5.14e-04   1.18e+01
#    800| 3.75e-04    3.47e-04     1.44e-04   1.37e+01
#    900| 3.12e-04    2.71e-04     1.54e-04   1.52e+01
#   1000| 2.42e-04    2.24e-04     9.13e-05   1.67e+01
#   1100| 3.14e-04    1.92e-04     2.48e-04   1.83e+01
#   1200| 1.75e-04    1.72e-04     2.95e-05   1.97e+01
#   1300| 1.23e-04    1.21e-04     2.38e-05   2.15e+01
#   1400| 9.79e-05    8.74e-05     4.41e-05   2.36e+01
#   1500| 8.66e-05    8.66e-05     2.85e-06   2.53e+01
#   1600| 8.66e-05    8.66e-05     1.83e-07   2.70e+01
#   1700| 1.61e-04    7.59e-05     1.42e-04   2.88e+01
#   1800| 6.55e-05    6.31e-05     1.74e-05   3.06e+01
#   1900| 6.29e-05    6.29e-05     2.57e-07   3.21e+01
#   1999| 6.29e-05    6.29e-05     1.84e-08   3.36e+01
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 3.36e+01
# Total number of iterations: 2000
# Best total residual: 6.29e-05; reached at iteration 1944
# ======================================================================
# DRS finished.
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 2000, t_init (after preconditioning) = 8.59
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = True, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 20
# variables n = 11000, constraints m = 4000
# nnz(A) = 18000
# Setup time: 1.87e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.54e+01    3.96e+00     1.49e+01   6.15e-02
#    100| 2.54e-02    8.93e-03     2.38e-02   3.12e+00
#    200| 1.64e-03    9.65e-04     1.32e-03   5.84e+00
#    300| 5.88e-04    4.93e-04     3.20e-04   8.42e+00
#    400| 4.28e-04    3.61e-04     2.29e-04   1.09e+01
#    500| 2.48e-04    2.40e-04     6.37e-05   1.36e+01
#    600| 2.00e-04    1.82e-04     8.25e-05   1.71e+01
#    700| 1.46e-04    1.21e-04     8.01e-05   2.00e+01
#    800| 1.23e-04    1.09e-04     5.72e-05   2.25e+01
#    900| 7.59e-05    7.59e-05     3.96e-07   2.50e+01
#   1000| 6.34e-05    6.29e-05     7.71e-06   2.79e+01
#   1100| 4.73e-06    1.15e-06     4.58e-06   3.04e+01
#   1125| 1.10e-06    1.68e-07     1.09e-06   3.09e+01
# ----------------------------------------------------
# Status: Solved
# Solve time:
# ----------------------------------------------------------------------------
# Status: Solved/Inaccurate
# Hit max_iters, solution may be inaccurate, returning best found solution.
# Timing: Solve time: 3.28e+01s
# 	Lin-sys: nnz in L factor: 1307178, avg solve time: 4.80e-03s
# 	Cones: avg projection time: 1.11e-05s
# 	Acceleration: avg step time: 1.36e-03s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 6.3665e-12, dist(y, K*) = 1.8190e-12, s'y/|s||y| = 9.3732e-17
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 4.1743e-02
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 6.0816e-02
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 3.6302e-05
# ----------------------------------------------------------------------------
# c'x = 32648.9091, -b'y = 32646.5388
# ============================================================================
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 18.53
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = False, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 4600, constraints m = 3150
# nnz(A) = 658650
# Setup time: 1.08e-01
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 2.13e+01    2.13e+01     0.00e+00   8.22e-01
#    100| 4.22e-02    4.00e-02     1.33e-02   7.82e+01
#    200| 2.93e-03    2.77e-03     9.34e-04   1.58e+02
#    300| 2.54e-04    2.41e-04     7.90e-05   2.21e+02
#    400| 2.32e-05    2.22e-05     7.01e-06   2.91e+02
#    500| 2.25e-06    2.15e-06     6.56e-07   3.49e+02
#    527| 1.21e-06    1.16e-06     3.50e-07   3.65e+02
# ----------------------------------------------------
# Status: Solved
# Solve time: 3.65e+02
# Total number of iterations: 528
# Best total residual: 1.21e-06; reached at iteration 527
# ======================================================================
# Finished DRS.
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 18.53
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = True, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 4600, constraints m = 3150
# nnz(A) = 658650
# Setup time: 1.09e-01
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 2.13e+01    2.13e+01     0.00e+00   8.07e-01
#     82| 9.69e-07    8.22e-07     5.14e-07   6.70e+01
# ----------------------------------------------------
# Status: Solved
# Solve time: 6.70e+01
# Total number of iterations: 83
# Best total residual: 9.69e-07; reached at iteration 82
# ======================================================================
# Finished A2DR.
# linear constr vio cvxpy = 0.6244702294775928, linear constr_vio a2dr = 9.285185555518088e-07
# norm constr vio cvxpy = 1.4236895677277528, norm constr vio a2dr = 1.0
# objective cvxpy = 32648.909111088633, objective cvxpy raw = 36364.92682106147, objective a2dr = 37986.57967852998

# %%
# Coupled QP
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_coupled_qp('../figures/coupled_qp.pdf')
# Out:
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 12.23
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = False, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 2400, constraints m = 50
# nnz(A) = 120000
# Setup time: 4.48e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 5.19e+01    3.32e+01     3.98e+01   9.14e-01
#    100| 1.74e+00    1.74e+00     1.88e-02   6.65e+01
#    200| 1.38e-01    1.38e-01     1.25e-03   1.38e+02
#    300| 1.42e-02    1.42e-02     1.23e-04   2.15e+02
#    400| 1.68e-03    1.68e-03     1.42e-05   2.90e+02
#    500| 2.15e-04    2.15e-04     1.82e-06   3.70e+02
#    600| 2.87e-05    2.87e-05     2.45e-07   4.36e+02
#    700| 3.96e-06    3.96e-06     3.39e-08   5.07e+02
#    749| 1.51e-06    1.51e-06     1.37e-08   5.46e+02
# ----------------------------------------------------
# Status: Solved
# Solve time: 5.46e+02
# Total number of iterations: 750
# Best total residual: 1.51e-06; reached at iteration 749
# ======================================================================
# DRS finished.
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 12.23
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = True, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 2400, constraints m = 50
# nnz(A) = 120000
# Setup time: 7.12e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 5.19e+01    3.32e+01     3.98e+01   8.60e-01
#     57| 1.17e-06    1.17e-06     3.91e-08   3.83e+01
# ----------------------------------------------------
# Status: Solved
# Solve time: 3.83e+01
# Total number of iterations: 58
# Best total residual: 1.17e-06; reached at iteration 57
# ======================================================================
# A2DR finished.
# objective value of A2DR = 89696.99862846492
# constraint violation of A2DR = 1.2880757683973192e-05

# %%
# Multi-task Regularized Logistic Regression
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_multi_task_logistic('../figures/multitask_reglog.pdf')
# Out:
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 7.79
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = False, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 13000, constraints m = 8000
# nnz(A) = 1513000
# Setup time: 2.47e-01
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 2.88e+00    1.29e+00     2.58e+00   6.16e-01
#    100| 1.80e-01    1.54e-03     1.80e-01   3.51e+01
#    200| 8.73e-02    3.93e-04     8.73e-02   5.98e+01
#    300| 5.64e-02    1.76e-04     5.64e-02   8.61e+01
#    400| 4.09e-02    9.90e-05     4.09e-02   1.17e+02
#    500| 3.16e-02    6.33e-05     3.16e-02   1.47e+02
#    600| 2.54e-02    4.39e-05     2.54e-02   1.73e+02
#    700| 2.10e-02    3.21e-05     2.10e-02   2.01e+02
#    800| 1.78e-02    2.45e-05     1.78e-02   2.25e+02
#    900| 1.52e-02    1.93e-05     1.52e-02   2.47e+02
#    999| 1.33e-02    1.55e-05     1.33e-02   2.69e+02
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 2.69e+02
# Total number of iterations: 1000
# Best total residual: 1.33e-02; reached at iteration 999
# ======================================================================
# DRS finished.
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 7.79
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = True, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 13000, constraints m = 8000
# nnz(A) = 1513000
# Setup time: 3.04e-01
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 2.88e+00    1.29e+00     2.58e+00   7.21e-01
#    100| 2.19e-03    6.24e-05     2.18e-03   2.49e+01
#    200| 3.91e-04    2.01e-07     3.91e-04   4.53e+01
#    300| 7.09e-05    4.95e-08     7.09e-05   7.17e+01
#    400| 8.73e-06    5.24e-09     8.73e-06   9.85e+01
#    500| 1.47e-06    9.47e-10     1.47e-06   1.24e+02
#    532| 9.27e-07    3.64e-10     9.27e-07   1.30e+02
# ----------------------------------------------------
# Status: Solved
# Solve time: 1.30e+02
# Total number of iterations: 533
# Best total residual: 9.27e-07; reached at iteration 532
# ======================================================================
# A2DR finished.

# %% [markdown]
# ## Slowness and inaccuracy of scipy.optimize.nnls on NNLS

# %%
import numpy as np
from scipy import sparse
from scipy.optimize import nnls
import time
np.random.seed(1)
m, n = 10000, 8000
density = 0.001
X = sparse.random(m, n, density=density, data_rvs=np.random.randn)
y = np.random.randn(m)

# %%
# Solve with scipy.optimize.nnls
t0 = time.time()
res = nnls(sparse.csr_matrix(X).todense(),y)
t1 = time.time()
print('run time = {}'.format(t1-t0))
print('constraint violation = {}'.format(np.min(res[0])))
print('objective value = {}'.format(np.linalg.norm(X.dot(res[0]) - y)))
# Out:
# run time = 698.0029423236847
# constraint violation = 0.0
# objective value = 76.39864074482281

# %%
# Solve with OSQP
from cvxpy import *
beta = Variable(n)
obj = sum_squares(X*beta-y)
constr = [beta >= 0]
prob = Problem(Minimize(obj), constr)
prob.solve(solver='OSQP', verbose=True)
beta = beta.value
print('constraint violation = {}'.format(np.min(beta)))
print('objective value = {}'.format(np.linalg.norm(X.dot(beta)-y)))
# Out:
# -----------------------------------------------------------------
#            OSQP v0.6.0  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2019
# -----------------------------------------------------------------
# problem:  variables n = 18000, constraints m = 18000
#           nnz(P) + nnz(A) = 108000
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   3.93e+00   9.68e+02   1.00e-01   6.11e+01s
#  200   5.6140e+03   1.14e-01   2.72e-03   1.00e-01   7.27e+01s
#  400   5.8044e+03   2.25e-02   2.92e-04   1.00e-01   8.46e+01s
#  550   5.8368e+03   2.59e-06   5.65e-05   1.56e+00   1.54e+02s
# plsh   5.8368e+03   1.63e-15   5.98e-15   --------   2.21e+02s
#
# status:               solved
# solution polish:      successful
# number of iterations: 550
# optimal objective:    5836.7523
# run time:             2.21e+02s
# optimal rho estimate: 2.59e-01
#
# constraint violation = -1.4669704317854836e-19
# objective value = 76.39864074482281

# %%
# Solve with SCS
from cvxpy import *
beta = Variable(n)
obj = sum_squares(X*beta-y)
constr = [beta >= 0]
prob = Problem(Minimize(obj), constr)
prob.solve(solver='SCS', eps=1e-6, verbose=True)
beta = beta.value
print('constraint violation = {}'.format(np.min(beta)))
print('objective value = {}'.format(np.linalg.norm(X.dot(beta)-y)))
# Out:
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 88002
# eps = 1.00e-06, alpha = 1.50, max_iters = 5000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 8001, constraints m = 18002
# Cones:	linear vars: 8000
# 	soc vars: 10002, soc blks: 1
# Setup time: 9.89e+01s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 5.81e+20  7.38e+20  1.00e+00 -3.53e+22  1.09e+23  6.61e+22  1.42e-01
#    100| 8.34e-02  2.36e-01  5.01e-05  5.67e+03  5.67e+03  7.41e-15  8.76e+00
#    200| 1.13e-02  3.20e-02  2.06e-07  5.83e+03  5.83e+03  5.22e-15  1.73e+01
#    300| 2.50e-03  8.70e-03  9.28e-07  5.83e+03  5.83e+03  1.31e-15  2.53e+01
#    400| 1.80e-03  6.64e-03  1.02e-06  5.83e+03  5.83e+03  2.26e-15  3.31e+01
#    500| 6.31e-04  2.43e-03  5.20e-07  5.84e+03  5.84e+03  1.19e-15  4.10e+01
#    600| 5.07e-04  1.41e-03  2.95e-07  5.84e+03  5.84e+03  1.23e-15  5.15e+01
#    700| 6.10e-04  2.00e-03  7.68e-08  5.84e+03  5.84e+03  1.73e-15  6.09e+01
#    800| 2.92e-04  1.05e-03  1.27e-08  5.84e+03  5.84e+03  4.55e-15  7.41e+01
#    900| 4.29e-05  1.55e-04  8.11e-09  5.84e+03  5.84e+03  1.14e-14  8.64e+01
#   1000| 3.29e-05  1.04e-04  1.01e-08  5.84e+03  5.84e+03  8.27e-16  9.54e+01
#   1100| 2.36e-05  7.57e-05  6.43e-09  5.84e+03  5.84e+03  8.04e-15  1.04e+02
#   1200| 1.70e-05  5.76e-05  3.48e-09  5.84e+03  5.84e+03  1.12e-14  1.15e+02
#   1300| 1.22e-05  4.25e-05  3.46e-09  5.84e+03  5.84e+03  1.32e-14  1.25e+02
#   1400| 8.59e-06  2.87e-05  2.85e-09  5.84e+03  5.84e+03  3.95e-15  1.33e+02
#   1500| 5.10e-06  1.82e-05  6.32e-10  5.84e+03  5.84e+03  1.01e-14  1.41e+02
#   1600| 3.10e-06  1.25e-05  2.60e-10  5.84e+03  5.84e+03  3.16e-15  1.50e+02
#   1700| 2.07e-06  8.21e-06  2.55e-10  5.84e+03  5.84e+03  1.25e-15  1.58e+02
#   1800| 1.49e-06  5.64e-06  1.96e-10  5.84e+03  5.84e+03  6.41e-15  1.67e+02
#   1900| 9.40e-07  3.74e-06  2.21e-10  5.84e+03  5.84e+03  8.34e-15  1.77e+02
#   2000| 7.28e-07  2.43e-06  1.43e-10  5.84e+03  5.84e+03  6.32e-15  1.87e+02
#   2100| 4.98e-07  1.54e-06  8.85e-11  5.84e+03  5.84e+03  3.90e-15  1.96e+02
#   2200| 3.46e-07  9.97e-07  2.46e-11  5.84e+03  5.84e+03  1.14e-14  2.05e+02
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.05e+02s
# 	Lin-sys: nnz in L factor: 26759681, avg solve time: 8.87e-02s
# 	Cones: avg projection time: 6.48e-05s
# 	Acceleration: avg step time: 3.77e-03s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 4.3515e-14, dist(y, K*) = 0.0000e+00, s'y/|s||y| = 2.8598e-15
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 3.4561e-07
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 9.9702e-07
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 2.4649e-11
# ----------------------------------------------------------------------------
# c'x = 5836.7521, -b'y = 5836.7521
# ============================================================================
# constraint violation = -2.6528519914026893e-06
# objective value = 76.39864488654331

# %%
## NNLS (rerun)
tests = paper_plots.TestPaper()
tests.setUp()
tests.test_nnls('../figures/nnls_rerun.pdf')
# Out:
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 8.94
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = False, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 16000, constraints m = 8000
# nnz(A) = 16000
# Setup time: 2.16e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.23e+01    1.73e+00     1.22e+01   9.43e-02
#    100| 3.94e-02    7.55e-04     3.94e-02   6.19e+00
#    200| 2.26e-02    2.76e-04     2.26e-02   1.47e+01
#    300| 1.66e-02    1.53e-04     1.66e-02   2.23e+01
#    400| 1.33e-02    1.01e-04     1.33e-02   3.21e+01
#    500| 1.10e-02    7.52e-05     1.10e-02   3.98e+01
#    600| 9.21e-03    6.55e-05     9.21e-03   4.73e+01
#    700| 7.64e-03    5.37e-05     7.64e-03   5.75e+01
#    800| 6.36e-03    4.44e-05     6.36e-03   6.65e+01
#    900| 5.29e-03    3.69e-05     5.29e-03   7.40e+01
#    999| 4.41e-03    3.07e-05     4.41e-03   8.24e+01
# ----------------------------------------------------
# Status: Reach maximum iterations
# Solve time: 8.24e+01
# Total number of iterations: 1000
# Best total residual: 4.41e-03; reached at iteration 999
# ======================================================================
# Finish DRS.
# ----------------------------------------------------------------------
# a2dr v0.2.3.post3 - Prox-Affine Distributed Convex Optimization Solver
#                        (c) Anqi Fu, Junzi Zhang
#                       Stanford University   2019
# ----------------------------------------------------------------------
# ### Preconditioning starts ... ###
# ### Preconditioning finished.  ###
# max_iter = 1000, t_init (after preconditioning) = 8.94
# eps_abs = 1.00e-06, eps_rel = 1.00e-08, precond = True
# ada_reg = True, anderson = True, m_accel = 10
# lam_accel = 1.00e-08, aa_method = lstsq, D_safe = 1.00e+06
# eps_safe = 1.00e-06, M_safe = 10
# variables n = 16000, constraints m = 8000
# nnz(A) = 16000
# Setup time: 2.20e-02
# ----------------------------------------------------
#  iter | total res | primal res | dual res | time (s)
# ----------------------------------------------------
#      0| 1.23e+01    1.73e+00     1.22e+01   1.01e-01
#    100| 5.14e-03    1.78e-04     5.14e-03   9.60e+00
#    200| 1.52e-04    4.60e-06     1.52e-04   1.92e+01
#    300| 5.75e-06    1.65e-07     5.75e-06   2.74e+01
#    378| 1.12e-06    4.44e-08     1.12e-06   3.35e+01
# ----------------------------------------------------
# Status: Solved
# Solve time: 3.35e+01
# Total number of iterations: 379
# Best total residual: 1.12e-06; reached at iteration 378
# ======================================================================
# nonzero entries proportion = 0.498375
# Finish A2DR.
# run time of A2DR = 33.511154890060425
# constraint violation of A2DR = 0.0
# objective value of A2DR = 76.39864074485314
