# %%
cd ../..
# Out:
# /Users/junziz/Desktop/[Updated]Notes_for_Classes/SEMINARS/various_research/boyd_research/distributed_aa/cvxconsensus

# %%
import cvxconsensus

# %%
cd cvxconsensus/tests
# Out:
# /Users/junziz/Desktop/[Updated]Notes_for_Classes/SEMINARS/various_research/boyd_research/distributed_aa/cvxconsensus/cvxconsensus/tests

# %%
import test_solver

# %%
# NNLS
tests = test_solver.TestSolver()
tests.setUp()
tests.test_nnls()
# Out:
# Scipy Objective: 2477.2417812735484
# SciPy Solution: [0.         0.         0.         0.         0.1959873  1.24368535
#  2.16310638 3.39543364 4.95723158 5.39948327]
# DRS Objective: 2477.241793266621
# DRS Solution: [0.         0.         0.         0.         0.19585983 1.24380334
#  2.16329834 3.39545886 4.95695614 5.3993857 ]
# A2DR Objective: 2477.2417812735484
# A2DR Solution: [0.         0.         0.         0.         0.19598735 1.24368533
#  2.16310633 3.39543365 4.95723164 5.39948325]

# %%
# l1 Trend Filtering
tests = test_solver.TestSolver()
tests.setUp()
tests.test_l1_trend_filtering()
# Out:
# CVXPY Objective: 34.04583367003703
# CVXPY Solution: [ 0.73413612  0.16866208 -0.39681196 -0.34631533 -0.2958187  -0.24532206
#  -0.19482543 -0.16835778 -0.14189014 -0.15565406 -0.16941798 -0.1831819
#  -0.19694582 -0.21070974 -0.22447366 -0.23823759 -0.25200151 -0.26576543
#  -0.11719111  0.0313832   0.17995752  0.32853183  0.47710614  0.3400495
#   0.20299285  0.0659362  -0.07112045 -0.2081771  -0.28515019 -0.36212329
#  -0.43909639 -0.51606948 -0.59304258 -0.67001568 -0.48236645 -0.27231833
#  -0.06227021  0.14777791  0.35782603  0.21578059  0.07373516 -0.06831028
#   0.05175717  0.17182462  0.29189207  0.41195952  0.53202697  0.65209442
#   0.45117558  0.25025674  0.04933789 -0.15158095 -0.3524998  -0.1567108
#   0.0390782   0.2348672   0.4306562   0.46019067  0.45009301  0.43999536
#   0.4298977   0.41980004  0.40970238  0.39960472  0.52678749  0.65397025
#   0.78115301  0.90833578  0.47582218  0.02301012 -0.42980193 -0.36272298
# ...

# %%
# Single Commodity Flow
tests = test_solver.TestSolver()
tests.setUp()
tests.test_single_commodity_flow()
# Out:
# CVXPY Objective: 2.6208170983821573
# DRS Objective: 2.6208166553063315
# A2DR Objective: 2.620816887645815

# %%
# Sparse Inverse Covariance Estimation
tests = test_solver.TestSolver()
tests.setUp()
tests.test_sparse_covariance()
# Out:
# CVXPY Objective: 28.541734172332397
# DRS Objective: 28.542121944571303
# Process Process-35:
# Process Process-38:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "//anaconda/envs/MHP_MLE_OPT/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "//anaconda/envs/MHP_MLE_OPT/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "//anaconda/envs/MHP_MLE_OPT/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "//anaconda/envs/MHP_MLE_OPT/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/junziz/Desktop/[Updated]Notes_for_Classes/SEMINARS/various_research/boyd_research/distributed_aa/cvxconsensus/cvxconsensus/solver.py", line 37, in a2dr_worker
#     x_half = prox(v_vec, rho)
# ...

# %%
# Optimal Control
tests = test_solver.TestSolver()
tests.setUp()
tests.test_optimal_control()
# Out:
# CVXPY Objective: 76.83505992241325
# DRS Objective: 76.8356141626509
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-16-532457f274ab> in <module>
#       2 tests = test_solver.TestSolver()
#       3 tests.setUp()
# ----> 4 tests.test_optimal_control()
#
# ~/Desktop/[Updated]Notes_for_Classes/SEMINARS/various_research/boyd_research/distributed_aa/cvxconsensus/cvxconsensus/tests/test_solver.py in test_optimal_control(self)
#     607         drs_obj = calc_obj(drs_z)
#     608         print("DRS Objective:", drs_obj)
# --> 609         self.assertAlmostEqual(cvxpy_obj, drs_obj)
#     610         self.assertItemsAlmostEqual(cvxpy_x, drs_x)
#     611         self.assertItemsAlmostEqual(cvxpy_u, drs_u)
#
# ...

# %%
# Multi-scenario Optimal Control
tests = test_solver.TestSolver()
tests.setUp()
tests.test_multi_optimal_control()
# Out:
# CVXPY Objective: 17.030865804041305
# DRS Objective: 17.042425005378036
# A2DR Objective: 17.04649859314828

# %%
# Multi-task Regularized Logistic Regression
tests = test_solver.TestSolver()
tests.setUp()
tests.test_multi_task_logistic()
# Out:
# CVXPY Objective: 97.77510952888592
# Combined backtracking failed 90 0 0 0 sigma 0.0494444
# Combined backtracking failed 90 0 0 0 sigma 0.00380718
# Combined backtracking failed 90 0 0 0 sigma 0.120281
# Combined backtracking failed 90 0 0 0 sigma 0.21054
# Combined backtracking failed 90 0 0 0 sigma 0.0494444
# Combined backtracking failed 90 0 0 0 sigma 0.0091021
# Combined backtracking failed 90 0 0 0 sigma 0.0494444
# Combined backtracking failed 56 0 31 3 sigma 0.855349
# Process Process-72:
# Combined backtracking failed 90 0 0 0 sigma 0.0494444
# Traceback (most recent call last):
#   File "//anaconda/envs/MHP_MLE_OPT/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "//anaconda/envs/MHP_MLE_OPT/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# ...

# %%
import inspect
lines = inspect.getsource(test_solver)
print(lines)
# Out:
# """
# Copyright 2018 Anqi Fu
#
# This file is part of CVXConsensus.
#
# CVXConsensus is free software: you can redistribute it and/or modify
# it under the terms of the GNU General Public License as published by
# the Free Software Foundation, either version 3 of the License, or
# (at your option) any later version.
#
# CVXConsensus is distributed in the hope that it will be useful,
# but WITHOUT ANY WARRANTY; without even the implied warranty of
# MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the
# GNU General Public License for more details.
#
# You should have received a copy of the GNU General Public License
# along with CVXConsensus. If not, see <http://www.gnu.org/licenses/>.
# """
#
# import numpy as np
# import scipy as sp
# import numpy.linalg as LA
# import matplotlib.pyplot as plt
# from cvxpy import *
# from scipy.optimize import nnls
# from cvxconsensus import a2dr
# from cvxconsensus.tests.base_test import BaseTest
#
# ...
